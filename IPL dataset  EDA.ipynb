# %%
#import libraies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Ball_by_ball= pd.read_csv('Ball_By_Ball.csv')
match=pd.read_csv('Match.csv')
Player=pd.read_csv('Player_excel.csv')
Player_match=pd.read_csv('Player_match_excel1.csv',encoding= 'unicode_escape') 

Team=pd.read_csv('Team.csv')

# %%
##imported file in excel
df=pd.read_excel('batting_avg.xlsx')
df1=pd.read_excel('strike_rate.xlsx')
df2=pd.read_excel('captains.xlsx')
df3=pd.read_excel('fours_and_sixes.xlsx')

# %%
df3
# Out:
#              name       country  Batter  runs_from_fours  runs from sixes
# 0        W Jaffer         India       7               56               18
# 1      MV Boucher  South Africa      11              128               78
# 2      MEK Hussey     Australia      19              792              312
# 3        JDP Oram   New Zealand      22               24               30
# 4       SR Watson     Australia      32             1028              732
# ..            ...           ...     ...              ...              ...
# 283    TG Southee   New Zealand     377               12               18
# 284       D Wiese  South Africa     401               48               24
# 285  Ishan Kishan         India     410              136               78
# 286        P Sahu         India     412                4                6
# 287      K Rabada  South Africa     482               20                6
#
# [288 rows x 5 columns]

# %%
df1.columns=['player_name','player_country','strike_rate','Batter','runs']

# %%
df3.columns=['name','country','Batter','runs_from_fours','runs from sixes']

# %%
Ball_by_ball.head()
# Out:
#    MatcH_id  Over_id  Ball_id  Innings_No  Team_Batting  Team_Bowling  \
# 0    598028       15        6           1             5             2
# 1    598028       14        1           1             5             2
# 2    598028       14        2           1             5             2
# 3    598028       14        3           1             5             2
# 4    598028       14        4           1             5             2
#
#    Striker_Batting_Position Extra_Type  Runs_Scored  Extra_runs  ...  \
# 0                       6.0  No Extras            4           0  ...
# 1                       5.0  No Extras            1           0  ...
# 2                       3.0  No Extras            1           0  ...
# 3                       5.0  No Extras            1           0  ...
# 4                       3.0  No Extras            0           0  ...
#
#    Fielder_match_SK  Fielder_SK  Bowler_match_SK  BOWLER_SK  \
# 0                -1          -1            20343         82
# ...

# %%
match.head()
# Out:
#    Match_SK  match_id                        Team1  \
# 0         0    335987  Royal Challengers Bangalore
# 1         1    335988              Kings XI Punjab
# 2         2    335989             Delhi Daredevils
# 3         3    335990               Mumbai Indians
# 4         4    335991        Kolkata Knight Riders
#
#                          Team2 match_date  Season_Year  \
# 0        Kolkata Knight Riders  4/18/2008         2008
# 1          Chennai Super Kings  4/19/2008         2008
# 2             Rajasthan Royals  4/19/2008         2008
# 3  Royal Challengers Bangalore  4/20/2008         2008
# 4              Deccan Chargers  4/20/2008         2008
#
#                                    Venue_Name   City_Name Country_Name  \
# 0                       M Chinnaswamy Stadium   Bangalore        India
# 1  Punjab Cricket Association Stadium, Mohali  Chandigarh        India
# 2                            Feroz Shah Kotla       Delhi        India
# ...

# %%
team.head()
# Out:
#    Team_SK  Team_Id                    Team_Name
# 0        0        1        Kolkata Knight Riders
# 1        1        2  Royal Challengers Bangalore
# 2        2        3          Chennai Super Kings
# 3        3        4              Kings XI Punjab
# 4        4        5             Rajasthan Royals

# %%
Ball_by_ball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150451 entries, 0 to 150450
# Data columns (total 48 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   MatcH_id                  150451 non-null  int64
#  1   Over_id                   150451 non-null  int64
#  2   Ball_id                   150451 non-null  int64
#  3   Innings_No                150451 non-null  int64
#  4   Team_Batting              150451 non-null  int64
#  5   Team_Bowling              150451 non-null  int64
#  6   Striker_Batting_Position  136590 non-null  float64
#  7   Extra_Type                150451 non-null  object
#  8   Runs_Scored               150451 non-null  int64
#  9   Extra_runs                150451 non-null  int64
#  10  Wides                     150451 non-null  int64
#  11  Legbyes                   150451 non-null  int64
#  12  Byes                      150451 non-null  int64
# ...

# %%
Player.head()
# Out:
#    PLAYER_SK  Player_Id      Player_Name         DOB    Batting_hand  \
# 0          0          1       SC Ganguly  07-08-1972   Left-hand bat
# 1          1          2      BB McCullum   9/27/1981  Right-hand bat
# 2          2          3       RT Ponting  12/19/1974  Right-hand bat
# 3          3          4        DJ Hussey   7/15/1977  Right-hand bat
# 4          4          5  Mohammad Hafeez  10/17/1980  Right-hand bat
#
#         Bowling_skill Country_Name
# 0    Right-arm medium        India
# 1    Right-arm medium  New Zealand
# 2    Right-arm medium    Australia
# 3  Right-arm offbreak    Australia
# 4  Right-arm offbreak     Pakistan

# %%
Player_match.head()

# %% [markdown]
# ## DATA CLEANING OF BALL_BY_BALL DATASET

# %% [markdown]
# #summary/conclusion
# 1 total null count
# .Player_Out                  143013
#  Fielders                    145100
#  Striker_Batting_Position     13861
# 2.RangeIndex: 150451
# 3. duplicate=0
# 4.total match=636
# 5

# %%
Ball_by_ball.head()
# Out:
#    MatcH_id  Over_id  Ball_id  Innings_No  Team_Batting  Team_Bowling  \
# 0    598028       15        6           1             5             2
# 1    598028       14        1           1             5             2
# 2    598028       14        2           1             5             2
# 3    598028       14        3           1             5             2
# 4    598028       14        4           1             5             2
#
#    Striker_Batting_Position Extra_Type  Runs_Scored  Extra_runs  ...  \
# 0                       6.0  No Extras            4           0  ...
# 1                       5.0  No Extras            1           0  ...
# 2                       3.0  No Extras            1           0  ...
# 3                       5.0  No Extras            1           0  ...
# 4                       3.0  No Extras            0           0  ...
#
#    Fielder_match_SK  Fielder_SK  Bowler_match_SK  BOWLER_SK  \
# 0                -1          -1            20343         82
# ...

# %%
Ball_by_ball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150451 entries, 0 to 150450
# Data columns (total 48 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   MatcH_id                  150451 non-null  int64
#  1   Over_id                   150451 non-null  int64
#  2   Ball_id                   150451 non-null  int64
#  3   Innings_No                150451 non-null  int64
#  4   Team_Batting              150451 non-null  int64
#  5   Team_Bowling              150451 non-null  int64
#  6   Striker_Batting_Position  136590 non-null  float64
#  7   Extra_Type                150451 non-null  object
#  8   Runs_Scored               150451 non-null  int64
#  9   Extra_runs                150451 non-null  int64
#  10  Wides                     150451 non-null  int64
#  11  Legbyes                   150451 non-null  int64
#  12  Byes                      150451 non-null  int64
# ...

# %%
Ball_by_ball.describe()
# Out:
#            MatcH_id        Over_id        Ball_id     Innings_No  \
# count  1.504510e+05  150451.000000  150451.000000  150451.000000
# mean   6.362075e+05      10.142704       3.616639       1.482190
# std    2.343623e+05       5.674255       1.807638       0.501768
# min    3.359870e+05       1.000000       1.000000       1.000000
# 25%    4.191540e+05       5.000000       2.000000       1.000000
# 50%    5.483820e+05      10.000000       4.000000       1.000000
# 75%    8.297420e+05      15.000000       5.000000       2.000000
# max    1.082650e+06      20.000000       9.000000       4.000000
#
#         Team_Batting   Team_Bowling  Striker_Batting_Position    Runs_Scored  \
# count  150451.000000  150451.000000             136590.000000  150451.000000
# mean        5.346272       5.332806                  3.583637       1.222199
# std         3.217641       3.219607                  2.145090       1.594311
# ...

# %%
Ball_by_ball.isnull().sum()
# Out:
# MatcH_id                         0
# Over_id                          0
# Ball_id                          0
# Innings_No                       0
# Team_Batting                     0
# Team_Bowling                     0
# Striker_Batting_Position     13861
# Extra_Type                       0
# Runs_Scored                      0
# Extra_runs                       0
# Wides                            0
# Legbyes                          0
# Byes                             0
# Noballs                          0
# Penalty                          0
# Bowler_Extras                    0
# Out_type                         0
# Caught                           0
# Bowled                           0
# Run_out                          0
# LBW                              0
# Retired_hurt                     0
# Stumped                          0
# caught_and_bowled                0
# hit_wicket                       0
# ObstructingFeild                 0
# Bowler_Wicket                    0
# ...

# %%
Ball_by_ball[Ball_by_ball.duplicated()]
# Out:
# Empty DataFrame
# Columns: [MatcH_id, Over_id, Ball_id, Innings_No, Team_Batting, Team_Bowling, Striker_Batting_Position, Extra_Type, Runs_Scored, Extra_runs, Wides, Legbyes, Byes, Noballs, Penalty, Bowler_Extras, Out_type, Caught, Bowled, Run_out, LBW, Retired_hurt, Stumped, caught_and_bowled, hit_wicket, ObstructingFeild, Bowler_Wicket, Match_Date, Season, Striker, Non_Striker, Bowler, Player_Out, Fielders, Striker_match_SK, StrikerSK, NonStriker_match_SK, NONStriker_SK, Fielder_match_SK, Fielder_SK, Bowler_match_SK, BOWLER_SK, PlayerOut_match_SK, BattingTeam_SK, BowlingTeam_SK, Keeper_Catch, Player_out_sk, MatchDateSK]
# Index: []
#
# [0 rows x 48 columns]

# %%
Ball_by_ball['Over_id'].unique()
# Out:
# array([15, 14, 13, 12, 11, 10,  3,  2,  1, 16, 17, 18,  9,  8,  7, 20,  4,
#         5,  6, 19], dtype=int64)

# %%
Ball_by_ball['Ball_id'].unique()
# Out:
# array([6, 1, 2, 3, 4, 5, 7, 8, 9], dtype=int64)

# %%
Ball_by_ball['Innings_No'].unique()
# Out:
# array([1, 2, 4, 3], dtype=int64)

# %%
Ball_by_ball['MatcH_id'].nunique()
# Out:
# 636

# %%
Ball_by_ball['MatcH_id'].nunique()

# %%
Ball_by_ball['Non_Striker'].nunique()
# Out:
# 457

# %%
sum(Ball_by_ball['Caught']==1)
# Out:
# 4373

# %%
sum(Ball_by_ball['Stumped']==1)
# Out:
# 243

# %%
Ball_by_ball['Extra_Type'].unique()
# Out:
# array(['No Extras', 'wides', 'legbyes', 'byes', 'noballs', 'Legbyes',
#        'Byes', 'Wides', 'penalty', 'Noballs'], dtype=object)

# %% [markdown]
# ##list of metric ##
# Number of Innings Played as a Batsman (Innings)
# Number of Runs Scored (Runs)
# Number of Outs/Dismissals (Dismissals)
# Number of Balls Faced (Balls Faced)
# Number of 4s scored (4s)
# Number of 6s scored (6s)
# Highest Score (High Score)
# Number of Half Centuries scored (50)
# Number of Centuries scored (100)
# Batting Strike Rate (Strike Rate)
# Batting Average (Batting Average)

# %%
dfBall = Ball_by_ball.groupby('Striker')\
            .agg({'MatcH_id':'nunique','Runs_Scored':'sum','Ball_id':'count','Wides':'sum','Legbyes':'sum','Byes':'sum','Noballs':'sum'})\
            .reset_index()

# %%
dfBall
# Out:
#      Striker  MatcH_id  Runs_Scored  Ball_id  Wides  Legbyes  Byes  Noballs
# 0          1        56         1349     1326     77       30     2        6
# 1          2       103         2755     2181    128       55     9       18
# 2          3         9           91      129      2        7     4        0
# 3          4        61         1322     1101     33       15     9        5
# 4          5         8           64       84      1        3     1        0
# ..       ...       ...          ...      ...    ...      ...   ...      ...
# 455      490         1            3        2      0        0     0        0
# 456      491         3           38       31      0        0     0        0
# 457      495         3            8       11      0        1     0        0
# 458      496         3           19       26      0        0     0        0
# 459      497         5            9       12      0        1     2        0
#
# [460 rows x 8 columns]

# %%
dfBall.columns = ['Batter','Innings','Total_Runs','total_ball','wides','legbyes','byes','noball']

# %%
dfBall
# Out:
#      Batter  Innings  Total_Runs  total_ball  wides  legbyes  byes  noball
# 0         1       56        1349        1326     77       30     2       6
# 1         2      103        2755        2181    128       55     9      18
# 2         3        9          91         129      2        7     4       0
# 3         4       61        1322        1101     33       15     9       5
# 4         5        8          64          84      1        3     1       0
# ..      ...      ...         ...         ...    ...      ...   ...     ...
# 455     490        1           3           2      0        0     0       0
# 456     491        3          38          31      0        0     0       0
# 457     495        3           8          11      0        1     0       0
# 458     496        3          19          26      0        0     0       0
# 459     497        5           9          12      0        1     2       0
#
# [460 rows x 8 columns]

# %% [markdown]
# ## merging and adding new column in for batter

# %%
dfBall['ball_faced']=dfBall['total_ball']-dfBall['wides']-dfBall['legbyes']-dfBall['byes']-dfBall['noball']

# %%
dfBall
# Out:
#      Batter  Innings  Total_Runs  total_ball  wides  legbyes  byes  noball  \
# 0         1       56        1349        1326     77       30     2       6
# 1         2      103        2755        2181    128       55     9      18
# 2         3        9          91         129      2        7     4       0
# 3         4       61        1322        1101     33       15     9       5
# 4         5        8          64          84      1        3     1       0
# ..      ...      ...         ...         ...    ...      ...   ...     ...
# 455     490        1           3           2      0        0     0       0
# 456     491        3          38          31      0        0     0       0
# 457     495        3           8          11      0        1     0       0
# 458     496        3          19          26      0        0     0       0
# 459     497        5           9          12      0        1     2       0
#
#      ball_faced
# 0          1211
# 1          1971
# ...

# %%
dfBall.drop(['wides','legbyes','byes','noball','total_ball'],axis=1)
# Out:
#      Batter  Innings  Total_Runs  ball_faced
# 0         1       56        1349        1211
# 1         2      103        2755        1971
# 2         3        9          91         116
# 3         4       61        1322        1039
# 4         5        8          64          79
# ..      ...      ...         ...         ...
# 455     490        1           3           2
# 456     491        3          38          31
# 457     495        3           8          10
# 458     496        3          19          26
# 459     497        5           9           9
#
# [460 rows x 4 columns]

# %%
dfBall['batting_strike_rate']=((dfBall['Total_Runs']/dfBall['ball_faced'])*100).round(decimals=2)

# %%
dfBall
# Out:
#      Batter  Innings  Total_Runs  total_ball  wides  legbyes  byes  noball  \
# 0         1       56        1349        1326     77       30     2       6
# 1         2      103        2755        2181    128       55     9      18
# 2         3        9          91         129      2        7     4       0
# 3         4       61        1322        1101     33       15     9       5
# 4         5        8          64          84      1        3     1       0
# ..      ...      ...         ...         ...    ...      ...   ...     ...
# 455     490        1           3           2      0        0     0       0
# 456     491        3          38          31      0        0     0       0
# 457     495        3           8          11      0        1     0       0
# 458     496        3          19          26      0        0     0       0
# 459     497        5           9          12      0        1     2       0
#
#      ball_faced  batting_strike_rate
# ...

# %%
## total number of type player out
dfout = Ball_by_ball[(Ball_by_ball['Out_type']!="Not Applicable" )].groupby('Striker')['MatcH_id'].count().reset_index()

# %%
dfout
# Out:
#      Striker  MatcH_id
# 0          1        54
# 1          2       100
# 2          3         8
# 3          4        49
# 4          5         8
# ..       ...       ...
# 425      488        12
# 426      489         2
# 427      491         2
# 428      495         3
# 429      496         3
#
# [430 rows x 2 columns]

# %%
dfout.columns=['Batter','out_inning']

# %%
dfout
# Out:
#      Batter  out_inning
# 0         1          54
# 1         2         100
# 2         3           8
# 3         4          49
# 4         5           8
# ..      ...         ...
# 425     488          12
# 426     489           2
# 427     491           2
# 428     495           3
# 429     496           3
#
# [430 rows x 2 columns]

# %%
dfBall2=dfBall.merge(dfout,on='Batter',how='left')

# %%
dfBall2
# Out:
#      Batter  Innings  Total_Runs  total_ball  wides  legbyes  byes  noball  \
# 0         1       56        1349        1326     77       30     2       6
# 1         2      103        2755        2181    128       55     9      18
# 2         3        9          91         129      2        7     4       0
# 3         4       61        1322        1101     33       15     9       5
# 4         5        8          64          84      1        3     1       0
# ..      ...      ...         ...         ...    ...      ...   ...     ...
# 455     490        1           3           2      0        0     0       0
# 456     491        3          38          31      0        0     0       0
# 457     495        3           8          11      0        1     0       0
# 458     496        3          19          26      0        0     0       0
# 459     497        5           9          12      0        1     2       0
#
#      ball_faced  batting_strike_rate  out_inning
# ...

# %%
dfBall2['batting_avg']=(dfBall2['Total_Runs']/dfBall2['out_inning']).round(decimals=2)

# %%
dfBall2
# Out:
#      Batter  Innings  Total_Runs  total_ball  wides  legbyes  byes  noball  \
# 0         1       56        1349        1326     77       30     2       6
# 1         2      103        2755        2181    128       55     9      18
# 2         3        9          91         129      2        7     4       0
# 3         4       61        1322        1101     33       15     9       5
# 4         5        8          64          84      1        3     1       0
# ..      ...      ...         ...         ...    ...      ...   ...     ...
# 455     490        1           3           2      0        0     0       0
# 456     491        3          38          31      0        0     0       0
# 457     495        3           8          11      0        1     0       0
# 458     496        3          19          26      0        0     0       0
# 459     497        5           9          12      0        1     2       0
#
#      ball_faced  batting_strike_rate  out_inning  batting_avg
# ...

# %%
dfBall2.drop(['wides','legbyes','byes','noball','total_ball'],axis=1,inplace=True)

# %%
dfBall2
# Out:
#      Batter  Innings  Total_Runs  ball_faced  batting_strike_rate  out_inning  \
# 0         1       56        1349        1211               111.40        54.0
# 1         2      103        2755        1971               139.78       100.0
# 2         3        9          91         116                78.45         8.0
# 3         4       61        1322        1039               127.24        49.0
# 4         5        8          64          79                81.01         8.0
# ..      ...      ...         ...         ...                  ...         ...
# 455     490        1           3           2               150.00         NaN
# 456     491        3          38          31               122.58         2.0
# 457     495        3           8          10                80.00         3.0
# 458     496        3          19          26                73.08         3.0
# 459     497        5           9           9               100.00         NaN
#
#      batting_avg
# ...

# %%
## dfball3 is merge of dfball2 and strike dataset
dfBall3=dfBall2.merge(df1[['Batter','player_name','player_country']],on='Batter',how='left')

# %%
dfBall3
# Out:
#      Batter  Innings  Total_Runs  ball_faced  batting_strike_rate  out_inning  \
# 0         1       56        1349        1211               111.40        54.0
# 1         2      103        2755        1971               139.78       100.0
# 2         3        9          91         116                78.45         8.0
# 3         4       61        1322        1039               127.24        49.0
# 4         5        8          64          79                81.01         8.0
# ..      ...      ...         ...         ...                  ...         ...
# 455     490        1           3           2               150.00         NaN
# 456     491        3          38          31               122.58         2.0
# 457     495        3           8          10                80.00         3.0
# 458     496        3          19          26                73.08         3.0
# 459     497        5           9           9               100.00         NaN
#
# ...

# %%
dfBall4=dfBall3.merge(df3[['Batter','runs_from_fours','runs from sixes']],on='Batter',how='left')

# %%
dfBall4
# Out:
#      Batter  Innings  Total_Runs  ball_faced  batting_strike_rate  out_inning  \
# 0         1       56        1349        1211               111.40        54.0
# 1         2      103        2755        1971               139.78       100.0
# 2         3        9          91         116                78.45         8.0
# 3         4       61        1322        1039               127.24        49.0
# 4         5        8          64          79                81.01         8.0
# ..      ...      ...         ...         ...                  ...         ...
# 455     490        1           3           2               150.00         NaN
# 456     491        3          38          31               122.58         2.0
# 457     495        3           8          10                80.00         3.0
# 458     496        3          19          26                73.08         3.0
# 459     497        5           9           9               100.00         NaN
#
# ...

# %%
dfBall4['boundry_run%']=(((dfBall4['runs_from_fours']+dfBall4["runs from sixes"])/dfBall4['Total_Runs'])*100).round(decimals=2)

# %%
dfBall4
# Out:
#      Batter  Innings  Total_Runs  ball_faced  batting_strike_rate  out_inning  \
# 0         1       56        1349        1211               111.40        54.0
# 1         2      103        2755        1971               139.78       100.0
# 2         3        9          91         116                78.45         8.0
# 3         4       61        1322        1039               127.24        49.0
# 4         5        8          64          79                81.01         8.0
# ..      ...      ...         ...         ...                  ...         ...
# 455     490        1           3           2               150.00         NaN
# 456     491        3          38          31               122.58         2.0
# 457     495        3           8          10                80.00         3.0
# 458     496        3          19          26                73.08         3.0
# 459     497        5           9           9               100.00         NaN
#
# ...

# %%
dfBall4.to_csv('player_batting_dataset')

# %% [markdown]
# ## We use the same aggregation methods with a combination of conditional slicing by excluding all the wide balls for calculating the number of balls faced, by including all the runs which are 4s and boundaries for calculating the number of 4s scored and similarly for 6s.

# %%
dfdotball = Ball_by_ball[(Ball_by_ball['Runs_Scored']!= 0)].groupby('Bowler')['MatcH_id'].count().reset_index()

# %%
dfdotball
# Out:
#      Bowler  MatcH_id
# 0         1       195
# 1         4       225
# 2         5        35
# 3         8       200
# 4         9      1106
# ..      ...       ...
# 349     492        17
# 350     493        51
# 351     494        15
# 352     495        62
# 353     497        95
#
# [354 rows x 2 columns]

# %%
dfdotball.columns=['Bowler','Non_dotball']

# %%
dfdotball
# Out:
#      Bowler  Non_dotball
# 0         1          195
# 1         4          225
# 2         5           35
# 3         8          200
# 4         9         1106
# ..      ...          ...
# 349     492           17
# 350     493           51
# 351     494           15
# 352     495           62
# 353     497           95
#
# [354 rows x 2 columns]

# %%
A={'a':"1,2,3,4"}
B=A['a'!=[2,3]]
print(B)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25644\2689139771.py in <module>
#       1 A={'a':"1,2,3,4"}
# ----> 2 B=A['a'!=[2,3]]
#       3 print(B)
#
# KeyError: True

# %%
dfBowling = Ball_by_ball.groupby('Bowler').agg({'MatcH_id':'nunique','Runs_Scored':'sum','Bowler_Wicket':'sum','Extra_runs':'sum','Ball_id':'count'}).reset_index()

# %%
dfBowling
# Out:
#      Bowler  MatcH_id  Runs_Scored  Bowler_Wicket  Extra_runs  Ball_id
# 0         1        20          359             10          11      280
# 1         4        26          467              8          18      323
# 2         5         4           61              2          10       63
# 3         8        26          354              4          17      264
# 4         9        89         2222             65         126     1799
# ..      ...       ...          ...            ...         ...      ...
# 350     492         1           42              1           0       24
# 351     493         6          109              2           7       82
# 352     494         1           33              0           0       21
# 353     495         5          144              5          13      111
# 354     497        10          183              8           6      182
#
# [355 rows x 6 columns]

# %%
dfBowling.columns =['Bowler','bowl_inning','Runs_conceded','bowler_wicket','bowler_extraruns','ball_throw']

# %%
dfBowling
# Out:
#      Bowler  bowl_inning  Runs_conceded  bowler_wicket  bowler_extraruns  \
# 0         1           20            359             10                11
# 1         4           26            467              8                18
# 2         5            4             61              2                10
# 3         8           26            354              4                17
# 4         9           89           2222             65               126
# ..      ...          ...            ...            ...               ...
# 350     492            1             42              1                 0
# 351     493            6            109              2                 7
# 352     494            1             33              0                 0
# 353     495            5            144              5                13
# 354     497           10            183              8                 6
#
#      ball_throw
# 0           280
# 1           323
# 2            63
# 3           264
# ...

# %% [markdown]
# ## merging dfdotball and dfBowling and adding new column

# %%
dfBowling2=dfBowling.merge(dfdotball,on='Bowler',how='left')

# %%
dfBowling2
# Out:
#      Bowler  bowl_inning  Runs_conceded  bowler_wicket  bowler_extraruns  \
# 0         1           20            359             10                11
# 1         4           26            467              8                18
# 2         5            4             61              2                10
# 3         8           26            354              4                17
# 4         9           89           2222             65               126
# ..      ...          ...            ...            ...               ...
# 350     492            1             42              1                 0
# 351     493            6            109              2                 7
# 352     494            1             33              0                 0
# 353     495            5            144              5                13
# 354     497           10            183              8                 6
#
#      ball_throw  Non_dotball
# 0           280        195.0
# 1           323        225.0
# ...

# %%
dfBowling2['dot_ball %']=(((dfBowling2['ball_throw']-dfBowling2['Non_dotball'])/dfBowling2['ball_throw'])*100).round(decimals=2)

# %%
dfBowling2
# Out:
#      Bowler  bowl_inning  Runs_conceded  bowler_wicket  bowler_extraruns  \
# 0         1           20            359             10                11
# 1         4           26            467              8                18
# 2         5            4             61              2                10
# 3         8           26            354              4                17
# 4         9           89           2222             65               126
# ..      ...          ...            ...            ...               ...
# 350     492            1             42              1                 0
# 351     493            6            109              2                 7
# 352     494            1             33              0                 0
# 353     495            5            144              5                13
# 354     497           10            183              8                 6
#
#      ball_throw  Non_dotball  dot_ball  dot_ball %  bowling_avg
# ...

# %%
dfBowling2['bowling_avg']=(dfBowling2['Runs_conceded']/dfBowling2['bowler_wicket']).round(decimals=2)

# %%
dfBowling2
# Out:
#      Bowler  bowl_inning  Runs_conceded  bowler_wicket  bowler_extraruns  \
# 0         1           20            359             10                11
# 1         4           26            467              8                18
# 2         5            4             61              2                10
# 3         8           26            354              4                17
# 4         9           89           2222             65               126
# ..      ...          ...            ...            ...               ...
# 350     492            1             42              1                 0
# 351     493            6            109              2                 7
# 352     494            1             33              0                 0
# 353     495            5            144              5                13
# 354     497           10            183              8                 6
#
#      ball_throw  Non_dotball  dot_ball  dot_ball %  bowling_avg
# ...

# %%
dfBowling2['bowling_economy']=(dfBowling2['Runs_conceded']/(dfBowling2['ball_throw']/6)).round(decimals=2)

# %%
dfBowling2
# Out:
#      Bowler  bowl_inning  Runs_conceded  bowler_wicket  bowler_extraruns  \
# 0         1           20            359             10                11
# 1         4           26            467              8                18
# 2         5            4             61              2                10
# 3         8           26            354              4                17
# 4         9           89           2222             65               126
# ..      ...          ...            ...            ...               ...
# 350     492            1             42              1                 0
# 351     493            6            109              2                 7
# 352     494            1             33              0                 0
# 353     495            5            144              5                13
# 354     497           10            183              8                 6
#
#      ball_throw  Non_dotball  dot_ball  dot_ball %  bowling_avg  \
# ...

# %%
dfBowling2['bowling_strikerate']=(dfBowling2['ball_throw']/dfBowling2['bowler_wicket']).round(decimals=2)

# %%
dfBowling2
# Out:
#      Bowler  bowl_inning  Runs_conceded  bowler_wicket  bowler_extraruns  \
# 0         1           20            359             10                11
# 1         4           26            467              8                18
# 2         5            4             61              2                10
# 3         8           26            354              4                17
# 4         9           89           2222             65               126
# ..      ...          ...            ...            ...               ...
# 350     492            1             42              1                 0
# 351     493            6            109              2                 7
# 352     494            1             33              0                 0
# 353     495            5            144              5                13
# 354     497           10            183              8                 6
#
#      ball_throw  Non_dotball  dot_ball  dot_ball %  bowling_avg  \
# ...

# %%
dfBowling2['Batter']=dfBowling['Bowler']

# %%
dfBowling2.to_csv('player_bowling_dataset')

# %%
## now merge dfBowling2 and dfBall4(batting dataset
dfplayer=dfBall4.merge(dfBowling2,on='Batter',how='left')

# %%
dfplayer
# Out:
#      Batter  Innings  Total_Runs  ball_faced  batting_strike_rate  out_inning  \
# 0         1       56        1349        1211               111.40        54.0
# 1         2      103        2755        1971               139.78       100.0
# 2         3        9          91         116                78.45         8.0
# 3         4       61        1322        1039               127.24        49.0
# 4         5        8          64          79                81.01         8.0
# ..      ...      ...         ...         ...                  ...         ...
# 455     490        1           3           2               150.00         NaN
# 456     491        3          38          31               122.58         2.0
# 457     495        3           8          10                80.00         3.0
# 458     496        3          19          26                73.08         3.0
# 459     497        5           9           9               100.00         NaN
#
# ...

# %%
dfplayer2=dfBall4.merge(dfBowling2,on='Batter',how='outer')

# %%
dfplayer2
# Out:
#      Batter  Innings  Total_Runs  ball_faced  batting_strike_rate  out_inning  \
# 0         1     56.0      1349.0      1211.0               111.40        54.0
# 1         2    103.0      2755.0      1971.0               139.78       100.0
# 2         3      9.0        91.0       116.0                78.45         8.0
# 3         4     61.0      1322.0      1039.0               127.24        49.0
# 4         5      8.0        64.0        79.0                81.01         8.0
# ..      ...      ...         ...         ...                  ...         ...
# 488     486      NaN         NaN         NaN                  NaN         NaN
# 489     487      NaN         NaN         NaN                  NaN         NaN
# 490     492      NaN         NaN         NaN                  NaN         NaN
# 491     493      NaN         NaN         NaN                  NaN         NaN
# 492     494      NaN         NaN         NaN                  NaN         NaN
#
# ...

# %%
dfplayer.to_csv('player_dataset')

# %%
dfplayer2.to_csv('player_dataset2')

# %% [markdown]
# ### work on player_match dataset

# %%
Player_match
# Out:
#        Player_match_SK  PlayerMatch_key  Match_Id  Player_Id  \
# 0                12694     3.359870e+10    335987          6
# 1                12695     3.359870e+10    335987          7
# 2                12696     3.359870e+10    335987          8
# 3                12697     3.359870e+10    335987          9
# 4                12698     3.359870e+10    335987         10
# ...                ...              ...       ...        ...
# 13987            26681     1.080000e+11   1082650        413
# 13988            26682     1.080000e+11   1082650        430
# 13989            26683     1.080000e+11   1082650        483
# 13990            26684     1.080000e+11   1082650        488
# 13991            26685     1.080000e+11   1082650        497
#
#              Player_Name         DOB     Batting_hand           Bowling_skill  \
# 0               R Dravid  01-11-1973   Right-hand bat      Right-arm offbreak
# ...

# %%
dfmatch  = Player_match.groupby('Player_Id').agg({'Match_Id':'nunique','is_manofThematch':'sum','DOB':'unique'}).reset_index()

# %%
dfmatch
# Out:
#      Batter  total_match_play  ismom           DOB
# 0         1                59      5  [07-08-1972]
# 1         2               103      5   [9/27/1981]
# 2         3                10      0  [12/19/1974]
# 3         4                64      2   [7/15/1977]
# 4         5                 8      0  [10/17/1980]
# ..      ...               ...    ...           ...
# 492     493                 6      0   [5/27/1991]
# 493     494                 1      0  [02-01-1996]
# 494     495                 5      0  [08-12-1992]
# 495     496                 3      0  [12-02-1993]
# 496     497                11      0  [10-05-1999]
#
# [497 rows x 4 columns]

# %%
dfmatch.columns=['Batter','total_match_play','ismom','DOB']

# %%
dfplayer3=dfplayer2.merge(dfmatch,on='Batter',how='outer')

# %%
dfplayer3
# Out:
#      Batter  Innings  Total_Runs  ball_faced  batting_strike_rate  out_inning  \
# 0         1     56.0      1349.0      1211.0               111.40        54.0
# 1         2    103.0      2755.0      1971.0               139.78       100.0
# 2         3      9.0        91.0       116.0                78.45         8.0
# 3         4     61.0      1322.0      1039.0               127.24        49.0
# 4         5      8.0        64.0        79.0                81.01         8.0
# ..      ...      ...         ...         ...                  ...         ...
# 492     494      NaN         NaN         NaN                  NaN         NaN
# 493     466      NaN         NaN         NaN                  NaN         NaN
# 494     467      NaN         NaN         NaN                  NaN         NaN
# 495     468      NaN         NaN         NaN                  NaN         NaN
# 496     469      NaN         NaN         NaN                  NaN         NaN
#
# ...

# %%
dfplayer3.to_csv('player_dataset3')
